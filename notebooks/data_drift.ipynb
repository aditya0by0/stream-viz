# %%
# ------ River imports ---------

from river import stream

# Metrics
from river.metrics import Accuracy, Precision, Recall, F1, CohenKappa, BalancedAccuracy

# Drift Detectors
from river.drift import ADWIN, KSWIN, PageHinkley, DriftRetrainingClassifier
from river.drift.binary import *

# Classifiers
from river.linear_model import LogisticRegression
from river.forest import ARFClassifier
from river.tree import HoeffdingTreeClassifier, ExtremelyFastDecisionTreeClassifier

# %%
# ------ Sk-learn imports -------------

# sklearn classifiers
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# Sklearn Metric
from sklearn.metrics import cohen_kappa_score, accuracy_score, f1_score

# Others
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
# ------ Basic python lib imports ----------------
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpld3
import mplcursors
from collections import deque
import warnings
from scipy.stats import ks_2samp

warnings.filterwarnings("ignore")

# %%
# ------ Get "cfpdss" data --------------------------
df_cfpdss = pd.read_csv(
    "/Users/shreeyacy/GitHub/stream-viz/data/cfpdss.csv"
)
df_cfpdss.head()
# Out:
#   c5 c6 c7 c8 c9        n0        n1        n2        n3        n4 class
# 0  a  a  b  a  a  0.448573  1.212644  2.555515  0.242702  0.697604     A
# 1  a  a  a  b  b  1.902515 -0.467349 -0.744523 -0.017156 -0.380288     A
# 2  a  a  a  b  b  0.825045  1.002267  1.972207 -0.790095  0.233456     B
# 3  a  a  a  b  b -0.124974  0.902601  1.696092 -0.320182  0.243261     A
# 4  b  a  a  b  a -1.259765  0.793134  1.547527 -2.132172 -0.788367     B

# %%
# ------ Data pre-processing --------------
X_df = df_cfpdss.drop(columns="class")

# Separating categorical and non-categorical columns
categorical_columns = X_df.select_dtypes(include=["object"]).columns.tolist()
X_df_categorical = X_df[categorical_columns]
non_cat_columns = [col for col in X_df.columns if col not in categorical_columns]
X_df_non_categorical = X_df[non_cat_columns]

# One hot encoding - Categorical data
encoder = OneHotEncoder(sparse_output=False, drop="if_binary", dtype=np.int32)
one_hot_encoded = encoder.fit_transform(X_df_categorical)
columns = encoder.get_feature_names_out()
X_df_cat_one_hot = pd.DataFrame(one_hot_encoded, columns=columns)

# Feature scaling numerical data/non-categorical data
scaler = MinMaxScaler()
X_non_cat_df = pd.DataFrame(
    scaler.fit_transform(X_df_non_categorical), columns=scaler.get_feature_names_out()
)

# Concatenate categorical and non-categorical data
X_df_encoded = pd.concat(
    [
        X_df_cat_one_hot,
        X_non_cat_df,
    ],
    axis=1,
)

# Encoding the target variable
y_df = df_cfpdss[["class"]]
y_encoder = OneHotEncoder(sparse_output=False, drop="if_binary", dtype=np.int32)
y_one_hot = y_encoder.fit_transform(y_df)
y_encoded = pd.Series(y_one_hot.ravel())

# %%
window_size = 400
gap_size = 100

# Initialize the deque with the first 'window_size' elements
window_x = deque(y_encoded.head(window_size*2+100), maxlen=window_size*2+100)

# Function to get populations P1 and P2 from the deque
def get_population(window, window_size, gap_size):
    P1 = list(window)[:window_size]
    P2 = list(window)[window_size+gap_size:2*window_size+gap_size]
    return P1, P2

# Initialize P1 and P2
P1, P2 = get_population(window_x, window_size, gap_size)
pvalue = ks_2samp(P1, P2)[1]
if pvalue < 0.001:
    print(f"Gradual Drift Detected at {window_size} with p-value: {pvalue}")

# Iterate over the elements starting from window_size*2 + gap_size
for idx, xi in enumerate(y_encoded[window_size*2+gap_size:], start=window_size*2+gap_size):
    window_x.append(xi)  # Correctly append the new element to the deque
    P1, P2 = get_population(window_x, window_size, gap_size)
    pvalue = ks_2samp(P1, P2)[1]
    if pvalue < 0.0001:
        print(f"Gradual Drift Detected at {idx-(window_size+100)}")
# Out:
# Gradual Drift Detected at 3056
# Gradual Drift Detected at 3057
# Gradual Drift Detected at 3058
# Gradual Drift Detected at 3059
# Gradual Drift Detected at 3060
# Gradual Drift Detected at 3061
# Gradual Drift Detected at 3062
# Gradual Drift Detected at 3063
# Gradual Drift Detected at 3066
# Gradual Drift Detected at 3078
# Gradual Drift Detected at 3079
# Gradual Drift Detected at 3080
# Gradual Drift Detected at 3081
# Gradual Drift Detected at 3082
# Gradual Drift Detected at 3083
# Gradual Drift Detected at 3084
# Gradual Drift Detected at 3085
# Gradual Drift Detected at 3086
# Gradual Drift Detected at 3087
# Gradual Drift Detected at 3088
# Gradual Drift Detected at 3089
# Gradual Drift Detected at 3090
# Gradual Drift Detected at 3091
# Gradual Drift Detected at 3095
# Gradual Drift Detected at 3096
# Gradual Drift Detected at 3097
# Gradual Drift Detected at 3098
# Gradual Drift Detected at 3099
# Gradual Drift Detected at 3103
# Gradual Drift Detected at 3112
# Gradual Drift Detected at 3130
# Gradual Drift Detected at 3131
# Gradual Drift Detected at 3132
# Gradual Drift Detected at 3133
# Gradual Drift Detected at 3134
# Gradual Drift Detected at 3135
# Gradual Drift Detected at 3136
# Gradual Drift Detected at 3139
# Gradual Drift Detected at 3149
# Gradual Drift Detected at 3150
# Gradual Drift Detected at 3151
# Gradual Drift Detected at 3152
# Gradual Drift Detected at 3153
# Gradual Drift Detected at 3156
# Gradual Drift Detected at 3157
# Gradual Drift Detected at 3158
# Gradual Drift Detected at 3159
# Gradual Drift Detected at 3160
# Gradual Drift Detected at 3161
# Gradual Drift Detected at 3162
# Gradual Drift Detected at 3163
# Gradual Drift Detected at 3164
# Gradual Drift Detected at 3165
# Gradual Drift Detected at 3166
# Gradual Drift Detected at 3167
# Gradual Drift Detected at 3168
# Gradual Drift Detected at 3169
# Gradual Drift Detected at 3170
# Gradual Drift Detected at 3171
# Gradual Drift Detected at 3172
# Gradual Drift Detected at 3173
# Gradual Drift Detected at 3174
# Gradual Drift Detected at 3175
# Gradual Drift Detected at 3176
# Gradual Drift Detected at 3177
# Gradual Drift Detected at 3178
# Gradual Drift Detected at 3179
# Gradual Drift Detected at 3180
# Gradual Drift Detected at 3181
# Gradual Drift Detected at 3182
# Gradual Drift Detected at 3183
# Gradual Drift Detected at 3184
# Gradual Drift Detected at 3185
# Gradual Drift Detected at 3186
# Gradual Drift Detected at 3187
# Gradual Drift Detected at 3188
# Gradual Drift Detected at 3189
# Gradual Drift Detected at 3190
# Gradual Drift Detected at 3191
# Gradual Drift Detected at 3192
# Gradual Drift Detected at 3193
# Gradual Drift Detected at 3194
# Gradual Drift Detected at 3195
# Gradual Drift Detected at 3196
# Gradual Drift Detected at 3197
# Gradual Drift Detected at 3198
# Gradual Drift Detected at 3199
# Gradual Drift Detected at 3200
# Gradual Drift Detected at 3201
# Gradual Drift Detected at 3202
# Gradual Drift Detected at 3203
# Gradual Drift Detected at 3204
# Gradual Drift Detected at 3205
# Gradual Drift Detected at 3206
# Gradual Drift Detected at 3207
# Gradual Drift Detected at 3208
# Gradual Drift Detected at 3209
# Gradual Drift Detected at 3210
# Gradual Drift Detected at 3211
# Gradual Drift Detected at 3212
# Gradual Drift Detected at 3213
# Gradual Drift Detected at 3214
# Gradual Drift Detected at 3215
# Gradual Drift Detected at 3216
# Gradual Drift Detected at 3217
# Gradual Drift Detected at 3218
# Gradual Drift Detected at 3219
# Gradual Drift Detected at 3220
# Gradual Drift Detected at 3221
# Gradual Drift Detected at 3222
# Gradual Drift Detected at 3223
# Gradual Drift Detected at 3224
# Gradual Drift Detected at 3225
# Gradual Drift Detected at 3226
# Gradual Drift Detected at 3227
# Gradual Drift Detected at 3228
# Gradual Drift Detected at 3229
# Gradual Drift Detected at 3230
# Gradual Drift Detected at 3231
# Gradual Drift Detected at 3232
# Gradual Drift Detected at 3233
# Gradual Drift Detected at 3234
# Gradual Drift Detected at 3235
# Gradual Drift Detected at 3236
# Gradual Drift Detected at 3237
# Gradual Drift Detected at 3238
# Gradual Drift Detected at 3239
# Gradual Drift Detected at 3240
# Gradual Drift Detected at 3241
# Gradual Drift Detected at 3242
# Gradual Drift Detected at 3243
# Gradual Drift Detected at 3244
# Gradual Drift Detected at 3245
# Gradual Drift Detected at 3246
# Gradual Drift Detected at 3247
# Gradual Drift Detected at 3248
# Gradual Drift Detected at 3249
# Gradual Drift Detected at 3250
# Gradual Drift Detected at 3251
# Gradual Drift Detected at 3252
# Gradual Drift Detected at 3253
# Gradual Drift Detected at 3254
# Gradual Drift Detected at 3255
# Gradual Drift Detected at 3256
# Gradual Drift Detected at 3257
# Gradual Drift Detected at 3258
# Gradual Drift Detected at 3259
# Gradual Drift Detected at 3260
# Gradual Drift Detected at 3261
# Gradual Drift Detected at 3262
# Gradual Drift Detected at 3263
# Gradual Drift Detected at 3264
# Gradual Drift Detected at 3265
# Gradual Drift Detected at 3266
# Gradual Drift Detected at 3267
# Gradual Drift Detected at 3268
# Gradual Drift Detected at 3269
# Gradual Drift Detected at 3270
# Gradual Drift Detected at 3271
# Gradual Drift Detected at 3272
# Gradual Drift Detected at 3273
# Gradual Drift Detected at 3274
# Gradual Drift Detected at 3275
# Gradual Drift Detected at 3276
# Gradual Drift Detected at 3277
# Gradual Drift Detected at 3278
# Gradual Drift Detected at 3279
# Gradual Drift Detected at 3280
# Gradual Drift Detected at 3281
# Gradual Drift Detected at 3282
# Gradual Drift Detected at 3283
# Gradual Drift Detected at 3284
# Gradual Drift Detected at 3285
# Gradual Drift Detected at 3286
# Gradual Drift Detected at 3287
# Gradual Drift Detected at 3288
# Gradual Drift Detected at 3289
# Gradual Drift Detected at 3290
# Gradual Drift Detected at 3291
# Gradual Drift Detected at 3292
# Gradual Drift Detected at 3293
# Gradual Drift Detected at 3294
# Gradual Drift Detected at 3295
# Gradual Drift Detected at 3296
# Gradual Drift Detected at 3297
# Gradual Drift Detected at 3298
# Gradual Drift Detected at 3299
# Gradual Drift Detected at 3300
# Gradual Drift Detected at 3301
# Gradual Drift Detected at 3302
# Gradual Drift Detected at 3303
# Gradual Drift Detected at 3304
# Gradual Drift Detected at 3305
# Gradual Drift Detected at 3306
# Gradual Drift Detected at 3307
# Gradual Drift Detected at 3308
# Gradual Drift Detected at 3309
# Gradual Drift Detected at 3310
# Gradual Drift Detected at 3311
# Gradual Drift Detected at 3312
# Gradual Drift Detected at 3313
# Gradual Drift Detected at 3314
# Gradual Drift Detected at 3315
# Gradual Drift Detected at 3316
# Gradual Drift Detected at 3317
# Gradual Drift Detected at 3318
# Gradual Drift Detected at 3319
# Gradual Drift Detected at 3320
# Gradual Drift Detected at 3321
# Gradual Drift Detected at 3322
# Gradual Drift Detected at 3323
# Gradual Drift Detected at 3324
# Gradual Drift Detected at 3325
# Gradual Drift Detected at 3326
# Gradual Drift Detected at 3327
# Gradual Drift Detected at 3328
# Gradual Drift Detected at 3329
# Gradual Drift Detected at 3330
# Gradual Drift Detected at 3331
# Gradual Drift Detected at 3332
# Gradual Drift Detected at 3333
# Gradual Drift Detected at 3334
# Gradual Drift Detected at 3335
# Gradual Drift Detected at 3336
# Gradual Drift Detected at 3337
# Gradual Drift Detected at 3338
# Gradual Drift Detected at 3339
# Gradual Drift Detected at 5847
# Gradual Drift Detected at 5848
# Gradual Drift Detected at 5849
# Gradual Drift Detected at 5850
# Gradual Drift Detected at 5851
# Gradual Drift Detected at 5852
# Gradual Drift Detected at 5853
# Gradual Drift Detected at 5854
# Gradual Drift Detected at 5855
# Gradual Drift Detected at 5856
# Gradual Drift Detected at 5857
# Gradual Drift Detected at 5858
# Gradual Drift Detected at 5859
# Gradual Drift Detected at 5860
# Gradual Drift Detected at 5861
# Gradual Drift Detected at 5862
# Gradual Drift Detected at 5863
# Gradual Drift Detected at 5864
# Gradual Drift Detected at 5865
# Gradual Drift Detected at 5866
# Gradual Drift Detected at 5867
# Gradual Drift Detected at 5868
# Gradual Drift Detected at 5869
# Gradual Drift Detected at 5870
# Gradual Drift Detected at 5871
# Gradual Drift Detected at 5872
# Gradual Drift Detected at 5873
# Gradual Drift Detected at 5874
# Gradual Drift Detected at 5875
# Gradual Drift Detected at 5876
# Gradual Drift Detected at 5877
# Gradual Drift Detected at 5878
# Gradual Drift Detected at 5879
# Gradual Drift Detected at 5880
# Gradual Drift Detected at 5881
# Gradual Drift Detected at 5882
# Gradual Drift Detected at 5883
# Gradual Drift Detected at 5884
# Gradual Drift Detected at 5885
# Gradual Drift Detected at 5886
# Gradual Drift Detected at 5887
# Gradual Drift Detected at 5888
# Gradual Drift Detected at 5889
# Gradual Drift Detected at 5890
# Gradual Drift Detected at 5891
# Gradual Drift Detected at 5892
# Gradual Drift Detected at 5893
# Gradual Drift Detected at 5894
# Gradual Drift Detected at 5895
# Gradual Drift Detected at 5896
# Gradual Drift Detected at 5897
# Gradual Drift Detected at 5898
# Gradual Drift Detected at 5899
# Gradual Drift Detected at 5900
# Gradual Drift Detected at 5901
# Gradual Drift Detected at 5902
# Gradual Drift Detected at 5903
# Gradual Drift Detected at 5904
# Gradual Drift Detected at 5905
# Gradual Drift Detected at 5906
# Gradual Drift Detected at 5907
# Gradual Drift Detected at 5908
# Gradual Drift Detected at 5909
# Gradual Drift Detected at 5910
# Gradual Drift Detected at 5911
# Gradual Drift Detected at 5912
# Gradual Drift Detected at 5913
# Gradual Drift Detected at 5914
# Gradual Drift Detected at 5915
# Gradual Drift Detected at 5916
# Gradual Drift Detected at 5917
# Gradual Drift Detected at 5918
# Gradual Drift Detected at 5919
# Gradual Drift Detected at 5920
# Gradual Drift Detected at 5921
# Gradual Drift Detected at 5922
# Gradual Drift Detected at 5923
# Gradual Drift Detected at 5924
# Gradual Drift Detected at 5925
# Gradual Drift Detected at 5926
# Gradual Drift Detected at 5927
# Gradual Drift Detected at 5928
# Gradual Drift Detected at 5929
# Gradual Drift Detected at 5930
# Gradual Drift Detected at 5931
# Gradual Drift Detected at 5932
# Gradual Drift Detected at 5933
# Gradual Drift Detected at 5934
# Gradual Drift Detected at 5935
# Gradual Drift Detected at 5936
# Gradual Drift Detected at 5937
# Gradual Drift Detected at 5938
# Gradual Drift Detected at 5939
# Gradual Drift Detected at 5940
# Gradual Drift Detected at 5941
# Gradual Drift Detected at 5942
# Gradual Drift Detected at 5943
# Gradual Drift Detected at 5944
# Gradual Drift Detected at 5945
# Gradual Drift Detected at 5946
# Gradual Drift Detected at 5947
# Gradual Drift Detected at 5948
# Gradual Drift Detected at 5949
# Gradual Drift Detected at 5950
# Gradual Drift Detected at 5951
# Gradual Drift Detected at 5952
# Gradual Drift Detected at 5953
# Gradual Drift Detected at 5954
# Gradual Drift Detected at 5955
# Gradual Drift Detected at 5956
# Gradual Drift Detected at 5957
# Gradual Drift Detected at 5958
# Gradual Drift Detected at 5959
# Gradual Drift Detected at 5960
# Gradual Drift Detected at 5961
# Gradual Drift Detected at 5962
# Gradual Drift Detected at 5963
# Gradual Drift Detected at 5964
# Gradual Drift Detected at 5965
# Gradual Drift Detected at 5966
# Gradual Drift Detected at 5967
# Gradual Drift Detected at 5968
# Gradual Drift Detected at 5969
# Gradual Drift Detected at 5970
# Gradual Drift Detected at 5971
# Gradual Drift Detected at 5972
# Gradual Drift Detected at 5973
# Gradual Drift Detected at 5974
# Gradual Drift Detected at 5975
# Gradual Drift Detected at 5976
# Gradual Drift Detected at 5977
# Gradual Drift Detected at 5978
# Gradual Drift Detected at 5979
# Gradual Drift Detected at 5980
# Gradual Drift Detected at 5981
# Gradual Drift Detected at 5982
# Gradual Drift Detected at 5983
# Gradual Drift Detected at 5984
# Gradual Drift Detected at 5985
# Gradual Drift Detected at 5986
# Gradual Drift Detected at 5987
# Gradual Drift Detected at 5988
# Gradual Drift Detected at 5989
# Gradual Drift Detected at 5990
# Gradual Drift Detected at 5991
# Gradual Drift Detected at 5992
# Gradual Drift Detected at 5993
# Gradual Drift Detected at 5994
# Gradual Drift Detected at 5995
# Gradual Drift Detected at 5996
# Gradual Drift Detected at 5997
# Gradual Drift Detected at 5998
# Gradual Drift Detected at 5999
# Gradual Drift Detected at 6000
# Gradual Drift Detected at 6001
# Gradual Drift Detected at 6002
# Gradual Drift Detected at 6003
# Gradual Drift Detected at 6004
# Gradual Drift Detected at 6005
# Gradual Drift Detected at 6006
# Gradual Drift Detected at 6007
# Gradual Drift Detected at 6008
# Gradual Drift Detected at 6009
# Gradual Drift Detected at 6010
# Gradual Drift Detected at 6011
# Gradual Drift Detected at 6012
# Gradual Drift Detected at 6013
# Gradual Drift Detected at 6014
# Gradual Drift Detected at 6015
# Gradual Drift Detected at 6016
# Gradual Drift Detected at 6017
# Gradual Drift Detected at 6018
# Gradual Drift Detected at 6019
# Gradual Drift Detected at 6020
# Gradual Drift Detected at 6021
# Gradual Drift Detected at 6022
# Gradual Drift Detected at 6023
# Gradual Drift Detected at 6024
# Gradual Drift Detected at 6025
# Gradual Drift Detected at 6026
# Gradual Drift Detected at 6027
# Gradual Drift Detected at 6028
# Gradual Drift Detected at 6029
# Gradual Drift Detected at 6030
# Gradual Drift Detected at 6031
# Gradual Drift Detected at 6032
# Gradual Drift Detected at 6033
# Gradual Drift Detected at 6034
# Gradual Drift Detected at 6035
# Gradual Drift Detected at 6036
# Gradual Drift Detected at 6037
# Gradual Drift Detected at 6038
# Gradual Drift Detected at 6039
# Gradual Drift Detected at 6040
# Gradual Drift Detected at 6041
# Gradual Drift Detected at 6042
# Gradual Drift Detected at 6043
# Gradual Drift Detected at 6044
# Gradual Drift Detected at 6045
# Gradual Drift Detected at 6046
# Gradual Drift Detected at 6047
# Gradual Drift Detected at 6048
# Gradual Drift Detected at 6049
# Gradual Drift Detected at 6050
# Gradual Drift Detected at 6051
# Gradual Drift Detected at 6052
# Gradual Drift Detected at 6053
# Gradual Drift Detected at 6054
# Gradual Drift Detected at 6055
# Gradual Drift Detected at 6056
# Gradual Drift Detected at 6057
# Gradual Drift Detected at 6058
# Gradual Drift Detected at 6059
# Gradual Drift Detected at 6060
# Gradual Drift Detected at 6061
# Gradual Drift Detected at 6062
# Gradual Drift Detected at 6063
# Gradual Drift Detected at 6064
# Gradual Drift Detected at 6065
# Gradual Drift Detected at 6066
# Gradual Drift Detected at 6067
# Gradual Drift Detected at 6068
# Gradual Drift Detected at 6069
# Gradual Drift Detected at 6070
# Gradual Drift Detected at 6071
# Gradual Drift Detected at 6072
# Gradual Drift Detected at 6073
# Gradual Drift Detected at 6074
# Gradual Drift Detected at 6075
# Gradual Drift Detected at 6076
# Gradual Drift Detected at 6077
# Gradual Drift Detected at 6078
# Gradual Drift Detected at 6079
# Gradual Drift Detected at 6080
# Gradual Drift Detected at 6081
# Gradual Drift Detected at 6082
# Gradual Drift Detected at 6083
# Gradual Drift Detected at 6084
# Gradual Drift Detected at 6085
# Gradual Drift Detected at 6086
# Gradual Drift Detected at 6087
# Gradual Drift Detected at 6088
# Gradual Drift Detected at 6089
# Gradual Drift Detected at 6090
# Gradual Drift Detected at 6091
# Gradual Drift Detected at 6092
# Gradual Drift Detected at 6093
# Gradual Drift Detected at 6094
# Gradual Drift Detected at 6095
# Gradual Drift Detected at 6096
# Gradual Drift Detected at 6097
# Gradual Drift Detected at 6098
# Gradual Drift Detected at 6099
# Gradual Drift Detected at 6100
# Gradual Drift Detected at 6101
# Gradual Drift Detected at 6102
# Gradual Drift Detected at 6103
# Gradual Drift Detected at 6104
# Gradual Drift Detected at 6105
# Gradual Drift Detected at 6106
# Gradual Drift Detected at 6107
# Gradual Drift Detected at 6108
# Gradual Drift Detected at 6109
# Gradual Drift Detected at 6110
# Gradual Drift Detected at 6111
# Gradual Drift Detected at 6112
# Gradual Drift Detected at 6113
# Gradual Drift Detected at 6114
# Gradual Drift Detected at 6115
# Gradual Drift Detected at 6116
# Gradual Drift Detected at 6117
# Gradual Drift Detected at 6118
# Gradual Drift Detected at 6119
# Gradual Drift Detected at 6120
# Gradual Drift Detected at 6121
# Gradual Drift Detected at 6122
# Gradual Drift Detected at 6123
# Gradual Drift Detected at 6124
# Gradual Drift Detected at 6125
# Gradual Drift Detected at 6126
# Gradual Drift Detected at 6127
# Gradual Drift Detected at 6128
# Gradual Drift Detected at 6129
# Gradual Drift Detected at 6130
# Gradual Drift Detected at 6131
# Gradual Drift Detected at 6132
# Gradual Drift Detected at 6133
# Gradual Drift Detected at 6134
# Gradual Drift Detected at 6135
# Gradual Drift Detected at 6136
# Gradual Drift Detected at 6137
# Gradual Drift Detected at 6138
# Gradual Drift Detected at 6139
# Gradual Drift Detected at 6140
# Gradual Drift Detected at 6141
# Gradual Drift Detected at 6142
# Gradual Drift Detected at 6143
# Gradual Drift Detected at 6144
# Gradual Drift Detected at 6145
# Gradual Drift Detected at 6146
# Gradual Drift Detected at 6147
# Gradual Drift Detected at 6148
# Gradual Drift Detected at 6149
# Gradual Drift Detected at 6150
# Gradual Drift Detected at 6151
# Gradual Drift Detected at 6152
# Gradual Drift Detected at 6153
# Gradual Drift Detected at 6154
# Gradual Drift Detected at 6155
# Gradual Drift Detected at 6156
# Gradual Drift Detected at 6157
# Gradual Drift Detected at 6158
# Gradual Drift Detected at 6159
# Gradual Drift Detected at 6160
# Gradual Drift Detected at 6161
# Gradual Drift Detected at 6162
# Gradual Drift Detected at 6163
# Gradual Drift Detected at 6164
# Gradual Drift Detected at 6165
# Gradual Drift Detected at 6166
# Gradual Drift Detected at 6167
# Gradual Drift Detected at 6168
# Gradual Drift Detected at 6169
# Gradual Drift Detected at 6170
# Gradual Drift Detected at 6171
# Gradual Drift Detected at 6172
# Gradual Drift Detected at 6173
# Gradual Drift Detected at 6174
# Gradual Drift Detected at 6175
# Gradual Drift Detected at 6176
# Gradual Drift Detected at 6177
# Gradual Drift Detected at 6178
# Gradual Drift Detected at 6179
# Gradual Drift Detected at 6180
# Gradual Drift Detected at 6181
# Gradual Drift Detected at 6182
# Gradual Drift Detected at 6183
# Gradual Drift Detected at 6184
# Gradual Drift Detected at 6185
# Gradual Drift Detected at 6186
# Gradual Drift Detected at 6187
# Gradual Drift Detected at 6188
# Gradual Drift Detected at 6189
# Gradual Drift Detected at 6190
# Gradual Drift Detected at 6191
# Gradual Drift Detected at 6192
# Gradual Drift Detected at 6193
# Gradual Drift Detected at 6194
# Gradual Drift Detected at 6195
# Gradual Drift Detected at 6196
# Gradual Drift Detected at 6197
# Gradual Drift Detected at 6198
# Gradual Drift Detected at 6199
# Gradual Drift Detected at 6200
# Gradual Drift Detected at 6201
# Gradual Drift Detected at 6202
# Gradual Drift Detected at 6203
# Gradual Drift Detected at 6204
# Gradual Drift Detected at 6205
# Gradual Drift Detected at 6206
# Gradual Drift Detected at 6207
# Gradual Drift Detected at 6208
# Gradual Drift Detected at 6209
# Gradual Drift Detected at 6210
# Gradual Drift Detected at 6211
# Gradual Drift Detected at 6212
# Gradual Drift Detected at 6213
# Gradual Drift Detected at 6214
# Gradual Drift Detected at 6215
# Gradual Drift Detected at 6216
# Gradual Drift Detected at 6217
# Gradual Drift Detected at 6218
# Gradual Drift Detected at 6219
# Gradual Drift Detected at 6220
# Gradual Drift Detected at 6221
# Gradual Drift Detected at 6222
# Gradual Drift Detected at 6223
# Gradual Drift Detected at 6224
# Gradual Drift Detected at 6225
# Gradual Drift Detected at 6226
# Gradual Drift Detected at 6227
# Gradual Drift Detected at 6228
# Gradual Drift Detected at 6229
# Gradual Drift Detected at 6230
# Gradual Drift Detected at 6231
# Gradual Drift Detected at 6232
# Gradual Drift Detected at 6233
# Gradual Drift Detected at 6234
# Gradual Drift Detected at 6235
# Gradual Drift Detected at 6236
# Gradual Drift Detected at 6237
# Gradual Drift Detected at 6238
# Gradual Drift Detected at 6239
# Gradual Drift Detected at 6240
# Gradual Drift Detected at 6241
# Gradual Drift Detected at 6242
# Gradual Drift Detected at 6243
# Gradual Drift Detected at 6244
# Gradual Drift Detected at 6245
# Gradual Drift Detected at 6246
# Gradual Drift Detected at 6247
# Gradual Drift Detected at 6248
# Gradual Drift Detected at 6249
# Gradual Drift Detected at 6250
# Gradual Drift Detected at 6251
# Gradual Drift Detected at 6252
# Gradual Drift Detected at 6253
# Gradual Drift Detected at 6254
# Gradual Drift Detected at 6255
# Gradual Drift Detected at 6256
# Gradual Drift Detected at 6257
# Gradual Drift Detected at 6258
# Gradual Drift Detected at 6259
# Gradual Drift Detected at 6260
# Gradual Drift Detected at 6261
# Gradual Drift Detected at 6262
# Gradual Drift Detected at 6263
# Gradual Drift Detected at 6264
# Gradual Drift Detected at 6265
# Gradual Drift Detected at 6266
# Gradual Drift Detected at 6267
# Gradual Drift Detected at 6268
# Gradual Drift Detected at 6269
# Gradual Drift Detected at 6270
# Gradual Drift Detected at 6271
# Gradual Drift Detected at 6272
# Gradual Drift Detected at 6273
# Gradual Drift Detected at 6274
# Gradual Drift Detected at 6275
# Gradual Drift Detected at 6276
# Gradual Drift Detected at 6277
# Gradual Drift Detected at 6278
# Gradual Drift Detected at 6279
# Gradual Drift Detected at 6280
# Gradual Drift Detected at 6281
# Gradual Drift Detected at 6282
# Gradual Drift Detected at 6283
# Gradual Drift Detected at 6284
# Gradual Drift Detected at 6285
# Gradual Drift Detected at 6286
# Gradual Drift Detected at 6287
# Gradual Drift Detected at 6288
# Gradual Drift Detected at 6289
# Gradual Drift Detected at 6290
# Gradual Drift Detected at 6291
# Gradual Drift Detected at 6292
# Gradual Drift Detected at 6293
# Gradual Drift Detected at 6294
# Gradual Drift Detected at 6295
# Gradual Drift Detected at 6296
# Gradual Drift Detected at 6297
# Gradual Drift Detected at 6298
# Gradual Drift Detected at 6299
# Gradual Drift Detected at 6300
# Gradual Drift Detected at 6301
# Gradual Drift Detected at 6302
# Gradual Drift Detected at 6303
# Gradual Drift Detected at 6304
# Gradual Drift Detected at 6305
# Gradual Drift Detected at 6306
# Gradual Drift Detected at 6307
# Gradual Drift Detected at 6308
# Gradual Drift Detected at 6309
# Gradual Drift Detected at 6310
# Gradual Drift Detected at 6311
# Gradual Drift Detected at 6312
# Gradual Drift Detected at 6313
# Gradual Drift Detected at 6314
# Gradual Drift Detected at 6315
# Gradual Drift Detected at 6316
# Gradual Drift Detected at 6317
# Gradual Drift Detected at 6318
# Gradual Drift Detected at 6319
# Gradual Drift Detected at 6320
# Gradual Drift Detected at 6321
# Gradual Drift Detected at 6322
# Gradual Drift Detected at 6323
# Gradual Drift Detected at 6324
# Gradual Drift Detected at 6325
# Gradual Drift Detected at 6326
# Gradual Drift Detected at 6327
# Gradual Drift Detected at 6328
# Gradual Drift Detected at 6329
# Gradual Drift Detected at 6330
# Gradual Drift Detected at 6331
# Gradual Drift Detected at 6332
# Gradual Drift Detected at 6333
# Gradual Drift Detected at 6334
# Gradual Drift Detected at 6335
# Gradual Drift Detected at 6336
# Gradual Drift Detected at 6337
# Gradual Drift Detected at 6338
# Gradual Drift Detected at 6339
# Gradual Drift Detected at 6340
# Gradual Drift Detected at 6341
# Gradual Drift Detected at 6342
# Gradual Drift Detected at 6343
# Gradual Drift Detected at 6344
# Gradual Drift Detected at 6345
# Gradual Drift Detected at 6346
# Gradual Drift Detected at 6347
# Gradual Drift Detected at 6348
# Gradual Drift Detected at 6349
# Gradual Drift Detected at 6350
# Gradual Drift Detected at 6351
# Gradual Drift Detected at 6352
# Gradual Drift Detected at 6353
# Gradual Drift Detected at 6354
# Gradual Drift Detected at 6355
# Gradual Drift Detected at 6356
# Gradual Drift Detected at 6357
# Gradual Drift Detected at 6358
# Gradual Drift Detected at 6359
# Gradual Drift Detected at 6360
# Gradual Drift Detected at 6361
# Gradual Drift Detected at 6362
# Gradual Drift Detected at 6363
# Gradual Drift Detected at 6364
# Gradual Drift Detected at 6365
# Gradual Drift Detected at 6366
# Gradual Drift Detected at 6367
# Gradual Drift Detected at 6368
# Gradual Drift Detected at 6369
# Gradual Drift Detected at 6370
# Gradual Drift Detected at 6371
# Gradual Drift Detected at 6372
# Gradual Drift Detected at 6373
# Gradual Drift Detected at 6374
# Gradual Drift Detected at 6375
# Gradual Drift Detected at 6376
# Gradual Drift Detected at 6377
# Gradual Drift Detected at 6378
# Gradual Drift Detected at 6379
# Gradual Drift Detected at 6380
# Gradual Drift Detected at 6381
# Gradual Drift Detected at 6382
# Gradual Drift Detected at 6383
# Gradual Drift Detected at 6384
# Gradual Drift Detected at 6385
# Gradual Drift Detected at 6386
# Gradual Drift Detected at 6387
# Gradual Drift Detected at 6388
# Gradual Drift Detected at 6389
# Gradual Drift Detected at 6390
# Gradual Drift Detected at 6391
# Gradual Drift Detected at 6392
# Gradual Drift Detected at 6393
# Gradual Drift Detected at 6394
# Gradual Drift Detected at 6395
# Gradual Drift Detected at 6396
# Gradual Drift Detected at 6397
# Gradual Drift Detected at 6398
# Gradual Drift Detected at 6399
# Gradual Drift Detected at 6400
# Gradual Drift Detected at 6401
# Gradual Drift Detected at 6402
# Gradual Drift Detected at 6403
# Gradual Drift Detected at 6404
# Gradual Drift Detected at 6405
# Gradual Drift Detected at 6406
# Gradual Drift Detected at 6407
# Gradual Drift Detected at 6408
# Gradual Drift Detected at 6409
# Gradual Drift Detected at 6410
# Gradual Drift Detected at 6411
# Gradual Drift Detected at 6412
# Gradual Drift Detected at 6413
# Gradual Drift Detected at 6414
# Gradual Drift Detected at 6415
# Gradual Drift Detected at 6416
# Gradual Drift Detected at 6417
# Gradual Drift Detected at 6418
# Gradual Drift Detected at 6419
# Gradual Drift Detected at 6420
# Gradual Drift Detected at 6421
# Gradual Drift Detected at 6422
# Gradual Drift Detected at 6423
# Gradual Drift Detected at 6424
# Gradual Drift Detected at 6425
# Gradual Drift Detected at 6426
# Gradual Drift Detected at 6427
# Gradual Drift Detected at 6428
# Gradual Drift Detected at 6429
# Gradual Drift Detected at 6430
# Gradual Drift Detected at 6431
# Gradual Drift Detected at 6432
# Gradual Drift Detected at 6433
# Gradual Drift Detected at 6434
# Gradual Drift Detected at 6435
# Gradual Drift Detected at 6436
# Gradual Drift Detected at 6437
# Gradual Drift Detected at 6438
# Gradual Drift Detected at 6439
# Gradual Drift Detected at 6440
# Gradual Drift Detected at 6441
# Gradual Drift Detected at 6442
# Gradual Drift Detected at 6443
# Gradual Drift Detected at 6444
# Gradual Drift Detected at 6445
# Gradual Drift Detected at 6446
# Gradual Drift Detected at 6447
# Gradual Drift Detected at 6448
# Gradual Drift Detected at 6449
# Gradual Drift Detected at 6450
# Gradual Drift Detected at 6451
# Gradual Drift Detected at 6452
# Gradual Drift Detected at 6453
# Gradual Drift Detected at 6454
# Gradual Drift Detected at 6455
# Gradual Drift Detected at 6456
# Gradual Drift Detected at 6457
# Gradual Drift Detected at 6458
# Gradual Drift Detected at 6459
# Gradual Drift Detected at 6460
# Gradual Drift Detected at 6461
# Gradual Drift Detected at 6462
# Gradual Drift Detected at 6463
# Gradual Drift Detected at 6464
# Gradual Drift Detected at 6465
# Gradual Drift Detected at 6466
# Gradual Drift Detected at 6467
# Gradual Drift Detected at 6468
# Gradual Drift Detected at 6469
# Gradual Drift Detected at 6470
# Gradual Drift Detected at 6471
# Gradual Drift Detected at 6472
# Gradual Drift Detected at 6473
# Gradual Drift Detected at 6474
# Gradual Drift Detected at 6475
# Gradual Drift Detected at 6476
# Gradual Drift Detected at 6477
# Gradual Drift Detected at 6478
# Gradual Drift Detected at 6479
# Gradual Drift Detected at 6480
# Gradual Drift Detected at 6481
# Gradual Drift Detected at 6482
# Gradual Drift Detected at 6483
# Gradual Drift Detected at 6484
# Gradual Drift Detected at 6485
# Gradual Drift Detected at 6486
# Gradual Drift Detected at 6487
# Gradual Drift Detected at 6488
# Gradual Drift Detected at 6489
# Gradual Drift Detected at 6490
# Gradual Drift Detected at 6491
# Gradual Drift Detected at 6492
# Gradual Drift Detected at 6493
# Gradual Drift Detected at 6494
# Gradual Drift Detected at 6495
# Gradual Drift Detected at 6496
# Gradual Drift Detected at 6497
# Gradual Drift Detected at 6498
# Gradual Drift Detected at 6499
# Gradual Drift Detected at 6500
# Gradual Drift Detected at 6501
# Gradual Drift Detected at 6502
# Gradual Drift Detected at 6503
# Gradual Drift Detected at 6504
# Gradual Drift Detected at 6505
# Gradual Drift Detected at 6506
# Gradual Drift Detected at 6507
# Gradual Drift Detected at 6508
# Gradual Drift Detected at 6509
# Gradual Drift Detected at 6510
# Gradual Drift Detected at 6729
# Gradual Drift Detected at 6730
# Gradual Drift Detected at 6731
# Gradual Drift Detected at 6732
# Gradual Drift Detected at 6733
# Gradual Drift Detected at 6734
# Gradual Drift Detected at 6735
# Gradual Drift Detected at 6736
# Gradual Drift Detected at 6737
# Gradual Drift Detected at 6738
# Gradual Drift Detected at 6739
# Gradual Drift Detected at 6740
# Gradual Drift Detected at 6741
# Gradual Drift Detected at 6742
# Gradual Drift Detected at 6743
# Gradual Drift Detected at 6744
# Gradual Drift Detected at 6745
# Gradual Drift Detected at 6746
# Gradual Drift Detected at 6747
# Gradual Drift Detected at 6748
# Gradual Drift Detected at 6749
# Gradual Drift Detected at 6750
# Gradual Drift Detected at 6751
# Gradual Drift Detected at 6752
# Gradual Drift Detected at 6753
# Gradual Drift Detected at 6754
# Gradual Drift Detected at 6755
# Gradual Drift Detected at 6756
# Gradual Drift Detected at 6757
# Gradual Drift Detected at 6758
# Gradual Drift Detected at 6759
# Gradual Drift Detected at 6760
# Gradual Drift Detected at 6761
# Gradual Drift Detected at 6762
# Gradual Drift Detected at 6763
# Gradual Drift Detected at 6764
# Gradual Drift Detected at 6765
# Gradual Drift Detected at 6766
# Gradual Drift Detected at 6767
# Gradual Drift Detected at 6768
# Gradual Drift Detected at 6769
# Gradual Drift Detected at 6770
# Gradual Drift Detected at 6771
# Gradual Drift Detected at 6772
# Gradual Drift Detected at 6773
# Gradual Drift Detected at 6774
# Gradual Drift Detected at 6775
# Gradual Drift Detected at 6776
# Gradual Drift Detected at 6777
# Gradual Drift Detected at 6778
# Gradual Drift Detected at 6779
# Gradual Drift Detected at 6780
# Gradual Drift Detected at 6781
# Gradual Drift Detected at 6782
# Gradual Drift Detected at 6783
# Gradual Drift Detected at 6784
# Gradual Drift Detected at 6785
# Gradual Drift Detected at 6786
# Gradual Drift Detected at 6787
# Gradual Drift Detected at 6788
# Gradual Drift Detected at 6789
# Gradual Drift Detected at 6790
# Gradual Drift Detected at 6791
# Gradual Drift Detected at 6792
# Gradual Drift Detected at 6793
# Gradual Drift Detected at 6794
# Gradual Drift Detected at 6795
# Gradual Drift Detected at 6796
# Gradual Drift Detected at 6797
# Gradual Drift Detected at 6798
# Gradual Drift Detected at 6799
# Gradual Drift Detected at 6800
# Gradual Drift Detected at 6801
# Gradual Drift Detected at 6802
# Gradual Drift Detected at 6803
# Gradual Drift Detected at 6804
# Gradual Drift Detected at 6805
# Gradual Drift Detected at 6806
# Gradual Drift Detected at 6807
# Gradual Drift Detected at 6808
# Gradual Drift Detected at 6809
# Gradual Drift Detected at 6810
# Gradual Drift Detected at 6811
# Gradual Drift Detected at 6812
# Gradual Drift Detected at 6813
# Gradual Drift Detected at 6814
# Gradual Drift Detected at 6815
# Gradual Drift Detected at 6816
# Gradual Drift Detected at 6817
# Gradual Drift Detected at 6818
# Gradual Drift Detected at 6819
# Gradual Drift Detected at 6820
# Gradual Drift Detected at 6821
# Gradual Drift Detected at 6822
# Gradual Drift Detected at 6823
# Gradual Drift Detected at 6824
# Gradual Drift Detected at 6825
# Gradual Drift Detected at 6826
# Gradual Drift Detected at 6827
# Gradual Drift Detected at 6828
# Gradual Drift Detected at 6829
# Gradual Drift Detected at 6830
# Gradual Drift Detected at 6831
# Gradual Drift Detected at 6832
# Gradual Drift Detected at 6833
# Gradual Drift Detected at 6834
# Gradual Drift Detected at 6835
# Gradual Drift Detected at 6836
# Gradual Drift Detected at 6837
# Gradual Drift Detected at 6838
# Gradual Drift Detected at 6839
# Gradual Drift Detected at 6840
# Gradual Drift Detected at 6841
# Gradual Drift Detected at 6842
# Gradual Drift Detected at 6843
# Gradual Drift Detected at 6844
# Gradual Drift Detected at 6845
# Gradual Drift Detected at 6846
# Gradual Drift Detected at 6847
# Gradual Drift Detected at 6848
# Gradual Drift Detected at 6849
# Gradual Drift Detected at 6850
# Gradual Drift Detected at 6851
# Gradual Drift Detected at 6852
# Gradual Drift Detected at 6853
# Gradual Drift Detected at 6854
# Gradual Drift Detected at 6855
# Gradual Drift Detected at 6856
# Gradual Drift Detected at 6857
# Gradual Drift Detected at 6858
# Gradual Drift Detected at 6859
# Gradual Drift Detected at 6860
# Gradual Drift Detected at 6861
# Gradual Drift Detected at 6862
# Gradual Drift Detected at 6863
# Gradual Drift Detected at 6864
# Gradual Drift Detected at 6865
# Gradual Drift Detected at 6866
# Gradual Drift Detected at 6867
# Gradual Drift Detected at 6868
# Gradual Drift Detected at 6869
# Gradual Drift Detected at 6870
# Gradual Drift Detected at 6871
# Gradual Drift Detected at 6872
# Gradual Drift Detected at 6873
# Gradual Drift Detected at 6874
# Gradual Drift Detected at 6875
# Gradual Drift Detected at 6876
# Gradual Drift Detected at 6877
# Gradual Drift Detected at 6878
# Gradual Drift Detected at 6879
# Gradual Drift Detected at 6880
# Gradual Drift Detected at 6881
# Gradual Drift Detected at 6882
# Gradual Drift Detected at 6883
# Gradual Drift Detected at 6884
# Gradual Drift Detected at 6885
# Gradual Drift Detected at 6886
# Gradual Drift Detected at 6887
# Gradual Drift Detected at 6888
# Gradual Drift Detected at 6889
# Gradual Drift Detected at 6890
# Gradual Drift Detected at 6891
# Gradual Drift Detected at 6892
# Gradual Drift Detected at 6893
# Gradual Drift Detected at 6894
# Gradual Drift Detected at 6895
# Gradual Drift Detected at 6896
# Gradual Drift Detected at 6897
# Gradual Drift Detected at 6898
# Gradual Drift Detected at 6899
# Gradual Drift Detected at 6900
# Gradual Drift Detected at 6901
# Gradual Drift Detected at 6902
# Gradual Drift Detected at 6903
# Gradual Drift Detected at 6904
# Gradual Drift Detected at 6905
# Gradual Drift Detected at 6906
# Gradual Drift Detected at 6907
# Gradual Drift Detected at 6908
# Gradual Drift Detected at 6909
# Gradual Drift Detected at 6910
# Gradual Drift Detected at 6911
# Gradual Drift Detected at 6912
# Gradual Drift Detected at 6913
# Gradual Drift Detected at 6914
# Gradual Drift Detected at 6915
# Gradual Drift Detected at 6916
# Gradual Drift Detected at 6917
# Gradual Drift Detected at 6918
# Gradual Drift Detected at 6919
# Gradual Drift Detected at 6920
# Gradual Drift Detected at 6921
# Gradual Drift Detected at 6922
# Gradual Drift Detected at 6923
# Gradual Drift Detected at 6924
# Gradual Drift Detected at 6925
# Gradual Drift Detected at 6926
# Gradual Drift Detected at 6927
# Gradual Drift Detected at 6928
# Gradual Drift Detected at 6929
# Gradual Drift Detected at 6930
# Gradual Drift Detected at 6931
# Gradual Drift Detected at 6932
# Gradual Drift Detected at 6933
# Gradual Drift Detected at 6934
# Gradual Drift Detected at 6935
# Gradual Drift Detected at 6936
# Gradual Drift Detected at 6937
# Gradual Drift Detected at 6938
# Gradual Drift Detected at 6939
# Gradual Drift Detected at 6940
# Gradual Drift Detected at 6941
# Gradual Drift Detected at 6942
# Gradual Drift Detected at 6943
# Gradual Drift Detected at 6944
# Gradual Drift Detected at 6945
# Gradual Drift Detected at 6946
# Gradual Drift Detected at 6947
# Gradual Drift Detected at 6948
# Gradual Drift Detected at 6949
# Gradual Drift Detected at 6950
# Gradual Drift Detected at 6951
# Gradual Drift Detected at 6952
# Gradual Drift Detected at 6953
# Gradual Drift Detected at 6954
# Gradual Drift Detected at 6955
# Gradual Drift Detected at 6956
# Gradual Drift Detected at 6957
# Gradual Drift Detected at 6958
# Gradual Drift Detected at 6959
# Gradual Drift Detected at 6960
# Gradual Drift Detected at 6961
# Gradual Drift Detected at 6962
# Gradual Drift Detected at 6963
# Gradual Drift Detected at 6964
# Gradual Drift Detected at 6965
# Gradual Drift Detected at 6966
# Gradual Drift Detected at 6967
# Gradual Drift Detected at 6968
# Gradual Drift Detected at 6969
# Gradual Drift Detected at 6970
# Gradual Drift Detected at 6971
# Gradual Drift Detected at 6972
# Gradual Drift Detected at 6973
# Gradual Drift Detected at 6974
# Gradual Drift Detected at 6975
# Gradual Drift Detected at 6976
# Gradual Drift Detected at 6977
# Gradual Drift Detected at 6978
# Gradual Drift Detected at 6979
# Gradual Drift Detected at 6980
# Gradual Drift Detected at 6981
# Gradual Drift Detected at 6982
# Gradual Drift Detected at 6983
# Gradual Drift Detected at 6984
# Gradual Drift Detected at 6985
# Gradual Drift Detected at 6986
# Gradual Drift Detected at 6987
# Gradual Drift Detected at 6988
# Gradual Drift Detected at 6989
# Gradual Drift Detected at 6990
# Gradual Drift Detected at 6991
# Gradual Drift Detected at 6992
# Gradual Drift Detected at 6993
# Gradual Drift Detected at 6994
# Gradual Drift Detected at 6995
# Gradual Drift Detected at 6996
# Gradual Drift Detected at 6997
# Gradual Drift Detected at 6998
# Gradual Drift Detected at 6999
# Gradual Drift Detected at 7000
# Gradual Drift Detected at 7001
# Gradual Drift Detected at 7002
# Gradual Drift Detected at 7003
# Gradual Drift Detected at 7004
# Gradual Drift Detected at 7005
# Gradual Drift Detected at 7006
# Gradual Drift Detected at 7007
# Gradual Drift Detected at 7008
# Gradual Drift Detected at 7009
# Gradual Drift Detected at 7010
# Gradual Drift Detected at 7011
# Gradual Drift Detected at 7012
# Gradual Drift Detected at 7013
# Gradual Drift Detected at 7014
# Gradual Drift Detected at 7015
# Gradual Drift Detected at 7016
# Gradual Drift Detected at 7017
# Gradual Drift Detected at 7018
# Gradual Drift Detected at 7019
# Gradual Drift Detected at 7020
# Gradual Drift Detected at 7021
# Gradual Drift Detected at 7022
# Gradual Drift Detected at 7023
# Gradual Drift Detected at 7024
# Gradual Drift Detected at 7025
# Gradual Drift Detected at 7026
# Gradual Drift Detected at 7027
# Gradual Drift Detected at 7028
# Gradual Drift Detected at 7029
# Gradual Drift Detected at 7030
# Gradual Drift Detected at 7031
# Gradual Drift Detected at 7032
# Gradual Drift Detected at 7033
# Gradual Drift Detected at 7034
# Gradual Drift Detected at 7035
# Gradual Drift Detected at 7036
# Gradual Drift Detected at 7037
# Gradual Drift Detected at 7038
# Gradual Drift Detected at 7039
# Gradual Drift Detected at 7040
# Gradual Drift Detected at 7041
# Gradual Drift Detected at 7042
# Gradual Drift Detected at 7043
# Gradual Drift Detected at 7044
# Gradual Drift Detected at 7045
# Gradual Drift Detected at 7046
# Gradual Drift Detected at 7047
# Gradual Drift Detected at 7048
# Gradual Drift Detected at 7049
# Gradual Drift Detected at 7050
# Gradual Drift Detected at 7051
# Gradual Drift Detected at 7052
# Gradual Drift Detected at 7053
# Gradual Drift Detected at 7054
# Gradual Drift Detected at 7055
# Gradual Drift Detected at 7056
# Gradual Drift Detected at 7057
# Gradual Drift Detected at 7058
# Gradual Drift Detected at 7059
# Gradual Drift Detected at 7060
# Gradual Drift Detected at 7061
# Gradual Drift Detected at 7062
# Gradual Drift Detected at 7063
# Gradual Drift Detected at 7064
# Gradual Drift Detected at 7065
# Gradual Drift Detected at 7066
# Gradual Drift Detected at 7067
# Gradual Drift Detected at 7068
# Gradual Drift Detected at 7069
# Gradual Drift Detected at 7070
# Gradual Drift Detected at 7071
# Gradual Drift Detected at 7072
# Gradual Drift Detected at 7073
# Gradual Drift Detected at 7074
# Gradual Drift Detected at 7075
# Gradual Drift Detected at 7076
# Gradual Drift Detected at 7077
# Gradual Drift Detected at 7078
# Gradual Drift Detected at 7079
# Gradual Drift Detected at 7080
# Gradual Drift Detected at 7081
# Gradual Drift Detected at 7082
# Gradual Drift Detected at 7083
# Gradual Drift Detected at 7084
# Gradual Drift Detected at 7085
# Gradual Drift Detected at 7086
# Gradual Drift Detected at 7087
# Gradual Drift Detected at 7088
# Gradual Drift Detected at 7089
# Gradual Drift Detected at 7090
# Gradual Drift Detected at 7091
# Gradual Drift Detected at 7092
# Gradual Drift Detected at 7093
# Gradual Drift Detected at 7094
# Gradual Drift Detected at 7095
# Gradual Drift Detected at 7096
# Gradual Drift Detected at 7097
# Gradual Drift Detected at 7098
# Gradual Drift Detected at 7099
# Gradual Drift Detected at 7100
# Gradual Drift Detected at 7101
# Gradual Drift Detected at 7102
# Gradual Drift Detected at 7103
# Gradual Drift Detected at 7104
# Gradual Drift Detected at 7105
# Gradual Drift Detected at 7106
# Gradual Drift Detected at 7107
# Gradual Drift Detected at 7108
# Gradual Drift Detected at 7109
# Gradual Drift Detected at 7110
# Gradual Drift Detected at 7111
# Gradual Drift Detected at 7112
# Gradual Drift Detected at 7113
# Gradual Drift Detected at 7114
# Gradual Drift Detected at 7115
# Gradual Drift Detected at 7116
# Gradual Drift Detected at 7117
# Gradual Drift Detected at 7118
# Gradual Drift Detected at 7119
# Gradual Drift Detected at 7120
# Gradual Drift Detected at 7121
# Gradual Drift Detected at 7122
# Gradual Drift Detected at 7123
# Gradual Drift Detected at 7124
# Gradual Drift Detected at 7125
# Gradual Drift Detected at 7126
# Gradual Drift Detected at 7127
# Gradual Drift Detected at 7128
# Gradual Drift Detected at 7129
# Gradual Drift Detected at 7130
# Gradual Drift Detected at 7131
# Gradual Drift Detected at 7132
# Gradual Drift Detected at 7133
# Gradual Drift Detected at 7134
# Gradual Drift Detected at 7135
# Gradual Drift Detected at 7136
# Gradual Drift Detected at 7137
# Gradual Drift Detected at 7138
# Gradual Drift Detected at 7139
# Gradual Drift Detected at 7140
# Gradual Drift Detected at 7141
# Gradual Drift Detected at 7142
# Gradual Drift Detected at 7143
# Gradual Drift Detected at 7144
# Gradual Drift Detected at 7145
# Gradual Drift Detected at 7146
# Gradual Drift Detected at 7147
# Gradual Drift Detected at 7148
# Gradual Drift Detected at 7149
# Gradual Drift Detected at 7150
# Gradual Drift Detected at 7151
# Gradual Drift Detected at 7152
# Gradual Drift Detected at 7153
# Gradual Drift Detected at 7154
# Gradual Drift Detected at 7155
# Gradual Drift Detected at 7156
# Gradual Drift Detected at 7157
# Gradual Drift Detected at 7158
# Gradual Drift Detected at 7159
# Gradual Drift Detected at 7160
# Gradual Drift Detected at 7161
# Gradual Drift Detected at 7162
# Gradual Drift Detected at 7163
# Gradual Drift Detected at 7164
# Gradual Drift Detected at 7165
# Gradual Drift Detected at 7166
# Gradual Drift Detected at 7167
# Gradual Drift Detected at 7168
# Gradual Drift Detected at 7169
# Gradual Drift Detected at 7170
# Gradual Drift Detected at 7171
# Gradual Drift Detected at 7172
# Gradual Drift Detected at 7173
# Gradual Drift Detected at 7174
# Gradual Drift Detected at 7175
# Gradual Drift Detected at 7176
# Gradual Drift Detected at 7177
# Gradual Drift Detected at 7178
# Gradual Drift Detected at 7179
# Gradual Drift Detected at 7180
# Gradual Drift Detected at 7181
# Gradual Drift Detected at 7182
# Gradual Drift Detected at 7183
# Gradual Drift Detected at 7184
# Gradual Drift Detected at 7185
# Gradual Drift Detected at 7186
# Gradual Drift Detected at 7187
# Gradual Drift Detected at 7188
# Gradual Drift Detected at 7189
# Gradual Drift Detected at 7190
# Gradual Drift Detected at 7191
# Gradual Drift Detected at 7192
# Gradual Drift Detected at 7193
# Gradual Drift Detected at 7194
# Gradual Drift Detected at 7195
# Gradual Drift Detected at 7196
# Gradual Drift Detected at 7197
# Gradual Drift Detected at 7198
# Gradual Drift Detected at 7199
# Gradual Drift Detected at 7200
# Gradual Drift Detected at 7201
# Gradual Drift Detected at 7202
# Gradual Drift Detected at 7203
# Gradual Drift Detected at 7204
# Gradual Drift Detected at 7205
# Gradual Drift Detected at 7206
# Gradual Drift Detected at 7207
# Gradual Drift Detected at 7208
# Gradual Drift Detected at 7209
# Gradual Drift Detected at 7210
# Gradual Drift Detected at 7211
# Gradual Drift Detected at 7212
# Gradual Drift Detected at 7213
# Gradual Drift Detected at 7214
